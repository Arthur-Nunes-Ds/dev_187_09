# %% [markdown]
# <strong> Crie um programa que liste 5 salas de cinema, e mostre os filmes de cada uma das salas e suas classificações indicativas. O usuário deverá informar sua idade e a sala com o filme desejado. Caso o usuário tenha a idade minima para ver o filme, o programa irá imprimir o ingresso para o filme desejado. Caso o usuário não tenha a idade mínima, o programa deverá informar que ele não tem idade para ver o filme, e deverá retomar a lista de filmes para que o usuário escolha outro filme.</strong>

# %%
#loop :)
print("="+10*"+=", "Seja bem-vindo ao CineVerse =", 14*"+=", end=2*"\n")
while True:
    # Printa a tabela de filmes 
    print("Idade Mínima |  Nome dos Filmes  | Sala")
    print("   Livre     |   Os Incríveis    |  03 ")
    print("    10       |  Kung Fu Panda 4  |  05 ")
    print("    12       |   Duna: Parte 2   |  10 ")
    print("    14       | Godzilla x Kong   |  08 ")
    print("    16       |   Nosso Sonho     |  06 ")
    print("    16       | Pobres Criaturas  |  01 ")  
    print("    18       | Jogos Mortais X   |  07 ")
    print("ATENÇÃO: SE OS DADOS APRESENTADOS NÃO CONDIZEREM COM OS DADOS INSERIDOS NO INGRESSO, ELE SERÁ INVÁLIDO")
    sala = input(f"{"\n"}Insira o número da sala do filme que você deseja: ")
    idade = input("Insira a sua idade: ")
    nome = input("Insira o seu nome: ")
    #tratamento de erro/converção de srt -> int sem try e exepect
    while (not str(sala).isdigit() or sala == "") or (not str(idade).isdigit() or idade == ""):
        print("Por favor, insira apenas números nesses campos:")
        sala = input(f"{3*" "}Insira o número da sala da sessão que você deseja: ")
        idade = input(f"{3*" "}Insira a sua idade: ")
        if sala.isdigit() and idade.isdigit():
            sala = int(sala)
            idade = int(idade)
            break
        else: continue
    else:
        sala = int(sala)
        idade = int(idade)

    # Seleção do filme
    # Pobres Criaturas
    if sala == 1:
        if idade >= 16:
            # Ingresso:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome do filme: \"Pobres Criaturas\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
        else:
            print("Você não tem idade para assistir esse filme")
    # Os Incríveis
    elif sala == 3:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome do filme: \"Os Incríveis\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
    # Kung Fu Panda 4
    elif sala == 5:
        if idade >= 10:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome da sessão: \"Kung Fu Panda 4\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
        else: 
            print("Você não tem idade para assistir esse filme")
    # Nosso Sonho
    elif sala == 6:
        if idade >= 16:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome do filme: \"Nosso Sonho\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
        else: 
            print("Você não tem idade para assistir esse filme")
    # Jogos Mortais X
    elif sala == 7:
        if idade >= 18:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome do filme: \"Jogos Mortais X\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
        else: 
            print("Você não tem idade para assistir esse filme")
    # Godzilla x Kong
    elif sala == 8:
        if idade >= 16:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome do filme: \"Godzilla x Kong\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
        else: 
            print("Você não tem idade para assistir esse filme")
    # Duna: Parte 2 
    elif sala == 10:
        if idade >= 14:
            print("="+15*"+=", "Ingressos do CineVerse =", 14*"+=")
            print(f"{3*" "}Sala: {sala}")
            print(f"{3*" "}Nome do filme: \"Duna: Parte 2\"")
            print(f"{3*" "}Nome do cliente: {nome}")
            print(f"{3*" "}Idade do cliente: {idade}")
            print("="+42*"+=")
            break
        else: 
            print("Você não tem idade para assistir esse filme")
    else:
        print("Opção inválida")
# Out:
# =+=+=+=+=+=+=+=+=+=+= Seja bem-vindo ao CineVerse = +=+=+=+=+=+=+=+=+=+=+=+=+=+=
#
# Idade Mínima |  Nome dos Filmes  | Sala
#    Livre     |   Os Incríveis    |  03
#     10       |  Kung Fu Panda 4  |  05
#     12       |   Duna: Parte 2   |  10
#     14       | Godzilla x Kong   |  08
#     16       |   Nosso Sonho     |  06
#     16       | Pobres Criaturas  |  01
#     18       | Jogos Mortais X   |  07
# ATENÇÃO: SE OS DADOS APRESENTADOS NÃO CONDIZEREM COM OS DADOS INSERIDOS NO INGRESSO, ELE SERÁ INVÁLIDO
# Por favor, insira apenas números nesses campos:
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+= Ingressos do CineVerse = +=+=+=+=+=+=+=+=+=+=+=+=+=+=
#    Sala: 3
#    Nome do filme: "Os Incríveis"
#    Nome do cliente: nuens
#    Idade do cliente: 12
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=
